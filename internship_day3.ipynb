# %% [markdown]
# <a href="https://colab.research.google.com/github/varsha943/Advanced-python/blob/main/internship_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def function(i):
   print(i*2)

function(10)
# Out:
# 20

# %%
def send_gift(recipients,gift):
  print(f"sending {gift} to {recipients}!")

send_gift("varsha","a camera")
# Out:
# sending a camera to varsha!

# %%
def send_gift(recipients,gift):
  print(f"sending {gift} to {recipients}!")
send_gift(gift="a camera",recipients="varsha")
# Out:
# sending a camera to varsha!

# %%
def book_trip(destination,transportation):
  print(f"booking {transportation} to {destination}!")
  book_trip(transportation="a flight",destination=" paris")
# Out:
# booking a flight to  paris!

# %%
#keyword
def book_trip(destination,transportation):
  print(f"booking {transportation} to {destination}!")
book_trip(transportation="flight", destination="paris")
# Out:
# booking flight to paris!

# %%
#default
def book_trip(destination,transportation="train"):
  print(f"booking {transportation} to {destination}!")
book_trip("paris","flight")
# Out:
# booking flight to paris!

# %%
#arbitary
def book_trip(*destination, transportation="train"):
  print(f"booking {transportation} to {destination}")
book_trip("paris","landon")
# Out:
# booking train to ('paris', 'landon')

# %%
#default
def book_trip(destination,transportation="train"):
  print(f"booking {transportation} to {destination}!")
book_trip("paris")

# %%
#return function(print used)
def add_number(a,b):
   print(a+b)

result = add_number(5,5)
# Out:
# 10

# %%
#return(return function used)
def add_number(a,b):
  return a+b

result= add_number(5,5)
final_answer = my_answer *2
print(final_answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2945774143.py in <cell line: 0>()
#       4
#       5 result= add_number(5,5)
# ----> 6 final_answer = my_answer *2
#       7 print(final_answer)
#
# NameError: name 'my_answer' is not defined

# %%
def add_ten(num):
  return num+18
my_result =add_ten(10)
final_answer=my_result*2
print(final_answer)
# Out:
# 56

# %%
def square(x):
  sq=x*x
  return sq

square(5)
# Out:
# 25

# %%
square=lambda x:x*x
square(5)
# Out:
# 25

# %%
addition=lambda x,y :x+y
print(addition(10,20))
# Out:
# 30

# %%
is_pass = lambda marks:"pass"if marks >40 else "fail"
is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq =x*x
  return sq

numbers=[1,2,3,4,5]
squares=map(square,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
def square (x):
  sq = x*x
  return sq

numbers=[1,2,3,4,5]
squares=map(lambda x:x*x,numbers)
list(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a =[1,2,3]
list_b=[4,5,6]
sum_lists=list(map(lambda x,y:x+y ,list_a,list_b))
sum_lists
# Out:
# [5, 7, 9]

# %%
a=[1,8,-8,-4,-5,7]
negative_num=list(filter(lambda x:x>0,a))
negative_num
# Out:
# [1, 8, 7]
